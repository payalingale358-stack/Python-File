# %% [markdown]
# ## String

# %%
var = "this is my first string"

# %%
type(var)
# Out:
# str

# %%
var[6]
# Out:
# 's'

# %%
var[-1]
# Out:
# 'g'

# %%
var[2:10]
# Out:
# 'is is my'

# %%
var[1::2]
# Out:
# 'hsi yfrtsrn'

# %%
var[::-1]
# Out:
# 'gnirts tsrif ym si siht'

# %%
var1 = "new string"

# %%
var1 + var
# Out:
# 'new stringthis is my first string'

# %%
var1 + " "+var
# Out:
# 'new string this is my first string'

# %%
(var1+ " " )*3
# Out:
# 'new string new string new string '

# %%
var[5] = "I"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 var[5] = "I"
#
# TypeError: 'str' object does not support item assignment

# %%
var
# Out:
# 'this is my first string'

# %%
"is " in var
# Out:
# True

# %%
var is var1
# Out:
# False

# %%
var = var.upper()

# %%
var.lower()
# Out:
# 'this is my first string'

# %%
var.capitalize()
# Out:
# 'This is my first string'

# %%
var.title()
# Out:
# 'This Is My First String'

# %%
var.isalpha()
# Out:
# False

# %%
var2 = "python"

# %%
var2.isalpha()
# Out:
# True

# %%
var.isnumeric()
# Out:
# False

# %%
var.startswith("t")
# Out:
# False

# %%
var.endswith("STRING")
# Out:
# True

# %%
var
# Out:
# 'THIS IS MY FIRST STRING'

# %%
var_len = var.center(80)

# %%
len(var_len)
# Out:
# 80

# %%
var_len
# Out:
# '                            THIS IS MY FIRST STRING                             '

# %%
var.find("i")
# Out:
# 2

# %%
var
# Out:
# 'this is my first string'

# %%
var.index("i")
# Out:
# 2

# %%
var.islower()
# Out:
# True

# %%
var.isupper()
# Out:
# False

# %%
var.removeprefix("this")
# Out:
# ' is my first string'

# %%
var.removesuffix(" string")
# Out:
# 'this is my first'

# %%
var2 = "this this is"

# %%
var2.removeprefix("this this")
# Out:
# ' is'

# %%
var2 = "            this is a single string          "

# %%
var2.lstrip()
# Out:
# 'this is a single string          '

# %%
var2.rstrip()
# Out:
# '            this is a single string'

# %%
var2.strip()
# Out:
# 'this is a single string'

# %%
var3 = "python&&&^^"

# %%
var3.rstrip("&^")
# Out:
# 'python'

# %%
var3.replace("&&&", "$")
# Out:
# 'python$^^'

# %%
var.replace("is", "IS")
# Out:
# 'thIS IS my first string'

# %%
var.partition("s")
# Out:
# ('thi', 's', ' is my first string')

# %%
var.rpartition("s")
# Out:
# ('this is my first ', 's', 'tring')

# %%
var.split("s")
# Out:
# ['thi', ' i', ' my fir', 't ', 'tring']

# %%
l1 = ["red", "yellow", "white", "black"]

# %%
l1
# Out:
# ['red', 'yellow', 'white', 'black']

# %%
" ".join(l1)
# Out:
# 'red yellow white black'

# %%
"".join(var.rpartition("s"))
# Out:
# 'this is my first string'

# %%
var5 = "PyThoN"

# %%
var5.swapcase()
# Out:
# 'pYtHOn'

# %% [markdown]
# ## Tuple

# %%
t1 = ("red", "yellow", "white", "black", 1,2,3,3,4)

# %%
t1[3]
# Out:
# 'black'

# %%
t1[-3]
# Out:
# 1

# %%
t1[2:]
# Out:
# ('white', 'black', 1, 2, 3)

# %%
t1[:4]
# Out:
# ('red', 'yellow', 'white', 'black')

# %%
t1 + t1
# Out:
# ('red',
#  'yellow',
#  'white',
#  'black',
#  1,
#  2,
#  3,
#  'red',
#  'yellow',
#  'white',
#  'black',
#  1,
#  2,
#  3)

# %%
t1 * 3
# Out:
# ('red',
#  'yellow',
#  'white',
#  'black',
#  1,
#  2,
#  3,
#  'red',
#  'yellow',
#  'white',
#  'black',
#  1,
#  2,
#  3,
#  'red',
#  'yellow',
#  'white',
#  'black',
#  1,
#  2,
#  3)

# %%
t2 = (4,5,6,7)

# %%
t1 + t2
# Out:
# ('red', 'yellow', 'white', 'black', 1, 2, 3, 4, 5, 6, 7)

# %%
t1 + var
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 t1 + var
#
# TypeError: can only concatenate tuple (not "str") to tuple

# %%
t1
# Out:
# ('red', 'yellow', 'white', 'black', 1, 2, 3)

# %%
"3 " in t1
# Out:
# False

# %%
3 in t1
# Out:
# True

# %%
t1 is t2
# Out:
# False

# %%
t1[3]  = "blue"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 t1[3]  = "blue"
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1.count(3)
# Out:
# 2

# %%
t1
# Out:
# ('red', 'yellow', 'white', 'black', 1, 2, 3, 3, 4)

# %%
t1.index("red")
# Out:
# 0

# %%
list(t1)
# Out:
# ['red', 'yellow', 'white', 'black', 1, 2, 3, 3, 4]

# %%
var.
