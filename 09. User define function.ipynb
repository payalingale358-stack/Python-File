# %%
def name_of_fun():
    return "C++"

# %%
name_of_fun()
# Out:
# 'C++'

# %%
name_of_fun()
# Out:
# 'C++'

# %%
print(234, 77, 9)
# Out:
# 234 77 9

# %%
len("345", "amit")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 len("345", "amit")
#
# TypeError: len() takes exactly one argument (2 given)

# %%
positional arguments 
non-keyword arguments
keyword arguments

# %%
parameters
arguments

# %%
def fun1(a):
    return a

# %%
fun1("amit")
# Out:
# 'amit'

# %%
def fun2(a):
    return a**2

# %%
fun2("4")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 fun2("4")
#
# Cell In[16], line 2, in fun2(a)
#       1 def fun2(a):
# ----> 2     return a**2
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %%
fun1()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 fun1()
#
# TypeError: fun1() missing 1 required positional argument: 'a'

# %%
fun1(2, 7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 fun1(2, 7)
#
# TypeError: fun1() takes 1 positional argument but 2 were given

# %%
fun1(5)
# Out:
# 5

# %%
def fun3(a, c):
    b = a + c
    return b

# %%
fun3( 3, 4)
# Out:
# 7

# %%
def fun4(*args):   # non keyword argument
    return args

# %%
fun4()
# Out:
# ()

# %%
fun4(3,4,7)
# Out:
# (3, 4, 7)

# %%
fun4(4345)
# Out:
# (4345,)

# %%
print(4, 7)
# Out:
# 4 7

# %%
def fun5(**kwargs):
    return kwargs

# %%
fun5(a = 6)
# Out:
# {'a': 6}

# %%
fun5()
# Out:
# {}

# %%
fun5(a = 10, b = 20 , c= 50)
# Out:
# {'a': 10, 'b': 20, 'c': 50}

# %%
def fun6(name, last_name = "kapoor"):
    return name + last_name

# %%
fun6("anil ")
# Out:
# 'anil kapoor'

# %%
fun6("anil ", last_name = "khan")
# Out:
# 'anil khan'

# %%
print()

# %%
def fun7(*a,  c, **b):
    return a,b,c

# %%
fun7(4, 6, x = 66)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 fun7(4, 6, x = 66)
#
# TypeError: fun7() missing 1 required keyword-only argument: 'c'

# %%
def fun7(*a,  c):
    return a,c

# %%
fun7(4, 8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 fun7(4, 8)
#
# TypeError: fun7() missing 1 required keyword-only argument: 'c'

# %%
def fun7(c, *a, **b):
    return a,b, c

# %%
fun7(3, 5, x= 8)
# Out:
# ((5,), {'x': 8}, 3)

# %%
def fun8(a,b):
    """this is a user defined function 
    created for math calculation"""
    a = a**2
    b = b**2
    return a*b

# %%
fun8(2,3)
# Out:
# 36

# %%
print()

# %%
# Global variable
x = "python"

# %%
def fun9(var):
    return x + var

# %%
fun9(" 3.13")
# Out:
# 'python 3.13'

# %%
x
# Out:
# 'python'

# %%
def fun10(var):
    y = "java"   #local variable
    return y + var

# %%
fun10(" 4.18")
# Out:
# 'java 4.18'

# %%
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 y
#
# NameError: name 'y' is not defined

# %%
def fun10(var):
    global y
    y = "java"  
    return y + var

# %%
fun10(" 4.19")
# Out:
# 'java 4.19'

# %%
y
# Out:
# 'java'

# %%
def mmtom(mm):
    m = mm/1000
    return f"{m} Meter"

# %%
mmtom(500)
# Out:
# '0.5 Meter'

# %%
def area(radius):
    pi = 3.14
    circle = pi*radius**2
    return f"{circle} square mm"

# %%
area(4)
# Out:
# '50.24 square mm'

# %%
def area1(area):
    if area=="circle":
        radius = float(input("radius"))
        circle_area = 3.14*radius**2
        return circle_area
    if area == "square":
        side = float(input("side"))
        square_area = side**2
        return square_area

# %%
area1("square")
# Out:
# side 30
# 900.0

# %%
def grade(mark):
    if mark < 0 or mark > 100: 
        print("Invalid marks are entered!")
    elif mark >= 0 and mark < 35 :
        print("Sorry you failed!")
    elif mark >= 36 and mark <= 60:
        print("You passed in second class")
    elif mark >= 61 and mark <= 80 :
        print("You passed in first class")
    else :
        print("You got distinction!")

# %%
grade(50)
# Out:
# You passed in second class

# %%
def pattern(rows):
    for i in range(rows + 1, 0, -1):
        # nested reverse loop
        for j in range(0, i - 1):
            # display star
            print("*", end=' ')
        print(" ")

# %%
pattern(4)
# Out:
# * * * *
# * * *
# * *
# *
