# %%
dict = {}

# %%
fruits_season = {
    "Mango": "Summer",
    "Orange": "Winter",
    "Banana": "All seasons",
    "Grapes": "Summer",
    "Strawberry": "Winter",
    "Watermelon": "Summer",
    "Pineapple": "All seasons",
    "Papaya": "All seasons"
}

# %%
month_colors = {
    "January": "White",
    "February": "Pink",
    "March": "Green",
    "April": "Yellow",
    "May": "Light Green",
    "June": "Orange",
    "July": "Red",
    "August": "Gold",
    "September": "Brown",
    "October": "Orange",
    "November": "Gray",
    "December": "Blue"
}

# %%
nested_dict = {
    "student": {
        "name": "Alex",
        "age": 15,                 # int
        "passed": True,            # bool
        "height": 5.6              # float
    },
    "subjects": ["Math", "Science", "English"],  # list
    "grades": {
        "Math": 88,
        "Science": 92,
        "English": 85
    },                              # dictionary
    "languages": {"Python", "Java", "C++"},  # set
    "exam_dates": ("March", "June", "September"),  # tuple
    "average_score": 88.3,          # float
    "is_active": True               # bool
}

# %%
fruits = {
    {"mango":"grapes"}: "Summer",
    "Orange": "Winter"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 fruits = {
#       2     {"mango":"grapes"}: "Summer",
#       3     "Orange": "Winter"}
#
# TypeError: unhashable type: 'dict'

# %%
fruits
# Out:
# {('mango', 'grapes'): 'Summer', 'Orange': 'Winter'}

# %%
fruits_season[4]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 fruits_season[4]
#
# KeyError: 4

# %%
fruits_season["Mango"]
# Out:
# 'Summer'

# %%
fruits_season[:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 fruits_season[:]
#
# TypeError: unhashable type: 'slice'

# %%
fruits + fruits_season
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 fruits + fruits_season
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
fruits*3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 fruits*3
#
# TypeError: unsupported operand type(s) for *: 'dict' and 'int'

# %%
fruits_season["Mango"]  = "all seasson"

# %%
fruits_season["Winter"] = "chiku"

# %%
fruits_season
# Out:
# {'Mango': 'all seasson',
#  'Orange': 'Winter',
#  'Banana': 'All seasons',
#  'Grapes': 'Summer',
#  'Strawberry': 'Winter',
#  'Watermelon': 'Summer',
#  'Pineapple': 'All seasons',
#  'Papaya': 'All seasons',
#  'Winter': 'chiku'}

# %%
{"Mango":"all seasson"} in fruits_season
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 {"Mango":"all seasson"} in fruits_season
#
# TypeError: unhashable type: 'dict'

# %%
{"Mango"} in fruits_season
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 {"Mango"} in fruits_season
#
# TypeError: unhashable type: 'set'

# %%
"Mango" in fruits_season
# Out:
# True

# %%
'all seasson' in fruits_season
# Out:
# False

# %%
fruits_season.get("Banana1")

# %%
fruits_season["Banana1"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 fruits_season["Banana1"]
#
# KeyError: 'Banana1'

# %%
fruits_season.keys()
# Out:
# dict_keys(['Mango', 'Orange', 'Banana', 'Grapes', 'Strawberry', 'Watermelon', 'Pineapple', 'Papaya', 'Winter'])

# %%
fruits_season.values()
# Out:
# dict_values(['all seasson', 'Winter', 'All seasons', 'Summer', 'Winter', 'Summer', 'All seasons', 'All seasons', 'chiku'])

# %%
fruits_season.items()
# Out:
# dict_items([('Mango', 'all seasson'), ('Orange', 'Winter'), ('Banana', 'All seasons'), ('Grapes', 'Summer'), ('Strawberry', 'Winter'), ('Watermelon', 'Summer'), ('Pineapple', 'All seasons'), ('Papaya', 'All seasons'), ('Winter', 'chiku')])

# %%
fruits_season.pop('Pineapple')
# Out:
# 'All seasons'

# %%
fruits_season.pop("Pineapple")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 fruits_season.pop("Pineapple")
#
# KeyError: 'Pineapple'

# %%
fruits_season.popitem()
# Out:
# ('Watermelon', 'Summer')

# %%
fruits_season
# Out:
# {'Mango': 'all seasson',
#  'Orange': 'Winter',
#  'Banana': 'All seasons',
#  'Grapes': 'Summer',
#  'Strawberry': 'Winter'}

# %%
fruits_season.update({"Watermelon":"summer", 'Papaya': 'All seasons'})

# %%
fruits_season
# Out:
# {'Mango': 'all seasson',
#  'Orange': 'Winter',
#  'Banana': 'All seasons',
#  'Grapes': 'Summer',
#  'Strawberry': 'Winter',
#  'Watermelon': 'summer',
#  'Papaya': 'All seasons'}

# %%
nested_dict
# Out:
# {'student': {'name': 'Alex', 'age': 15, 'passed': True, 'height': 5.6},
#  'subjects': ['Math', 'Science', 'English'],
#  'grades': {'Math': 88, 'Science': 92, 'English': 85},
#  'languages': {'C++', 'Java', 'Python'},
#  'exam_dates': ('March', 'June', 'September'),
#  'average_score': 88.3,
#  'is_active': True}

# %%
nested_dict["subjects"][2]
# Out:
# 'English'

# %%
nested_dict["student"]["passed"]
# Out:
# True

# %%
nested_dict["languages"]
# Out:
# {'C++', 'Java', 'Python'}

# %%
dict = {'student': {'name': 'Alex', 'age': 15, 'passed': True, 'height': 5.6,
                    'subjects': ['Math',{'exam_dates': ('March', 'June', 'September')},
                    'Science', 'English',
                    ('grades', 'Math', 88, 'Science')]}}

# %%
dict["student"]["subjects"][1]["exam_dates"][1]
# Out:
# 'June'

# %%
nested_dict["subjects"].append("history")

# %%
nested_dict["languages"].add("JS")

# %%
nested_dict
# Out:
# {'student': {'name': 'Alex', 'age': 15, 'passed': True, 'height': 5.6},
#  'subjects': ['Math', 'Science', 'English', 'history'],
#  'grades': {'Math': 88, 'Science': 92, 'English': 85},
#  'languages': {'C++', 'JS', 'Java', 'Python'},
#  'exam_dates': ('March', 'June', 'September'),
#  'average_score': 88.3,
#  'is_active': True}

# %%
l1 = ['Math', 'Science', 'English', 'history',('March', 'June', 'September', "March")]

# %%
l1[4].count("March")
# Out:
# 2

# %%
l1[2].
# Out:
# 'English'
