# %%
class person:
    def __init__ (self, name, lastname, profession):
        self.name = name
        self.lastname = lastname
        self.profession = profession

# %%
obj= person("rohit", "sharma", "cricketer")

# %%
obj.name
# Out:
# 'rohit'

# %%
class person1:
    
    def __init__ (self, name, lastname, profession):
        self.name = name                 #public variable
        self._lastname = lastname        #protective variable
        self.__profession = profession   #private variable

# %%
obj1 = person1("rohit", "sharma", "cricketer")

# %%
obj1.name
# Out:
# 'rohit'

# %%
obj1._lastname
# Out:
# 'sharma'

# %%
obj1._person1__profession
# Out:
# 'cricketer'

# %%
import pandas as pd

# %%
pd.

# %%
class person1:

    age = 30
    
    def __init__ (self, name, lastname, profession):
        self.name = name                 #public variable
        self._lastname = lastname        #protective variable
        self.__profession = profession   #private variable

# %%
obj2 = person1("rohit", "sharma", "cricketer")

# %%
obj2.

# %%
age
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 age
#
# NameError: name 'age' is not defined

# %%
class person1:

    _age = 30
    
    def __init__ (self, name, lastname, profession):
        self.name = name                 #public variable
        self._lastname = lastname        #protective variable
        self.__profession = profession   #private variable

# %%
obj2 = person1("rohit", "sharma", "cricketer")

# %%
obj2.name
# Out:
# 'rohit'

# %%
obj2._age
# Out:
# 30

# %%
class car:

    def __init__(self, brand, model, engine):
        self.brand = brand
        self.model = model
        self.engine = engine

    def _BMW(self):  #protective method
        pass

    def __TATA(self):  #private method
        pass

    def sakoda(self):  #public method
        pass

# %%
obje = car("TATA", "harrier", "v4")

# %%
obje.sakoda()

# %%
obje._BMW()

# %%
obje._car__TATA()

# %% [markdown]
# ## Inheritence

# %%
class person4:              # parents class

    name = "amit"
    surname = "kumar"
    yob = 1990

    def age(self , current_year ):
        return current_year - self.yob
    
    def age1(self , current_year ):
        return current_year - self.yob



class employee(person4):           #child class
    name = "amit"
    surname = "singh"
    yob = 1991

# %%
o1 = person4()

# %%
o2 = employee()

# %%
o1.age(2026)
# Out:
# 36

# %%
o2.age(2026)
# Out:
# 35

# %%
o1.yob
# Out:
# 1990

# %%
o2.yob
# Out:
# 1991

# %%
class person4:              # parents class

    name = "amit"
    surname = "kumar"
    yob = 1990

    def age(self , current_year ):
        return current_year - self.yob
    
    def age1(self , current_year ):
        return current_year - self.yob



class employee(person4):           #child class
    name = "amit"
    surname = "singh"
    yob = 1991

    def age(self ):    #method override
        return "this is chil method"

# %%
o1 = person4()
o2 = employee()

# %%
o1.surname
# Out:
# 'kumar'

# %%
o2.surname
# Out:
# 'singh'

# %%
o1.age(2026)
# Out:
# 36

# %%
o2.age()
# Out:
# 'this is chil method'

# %%
class car :                 #perent class   
                         # inheritence 
    def __init__(self , body , engin , tyre):
        self.body = body
        self.engin = engin
        self.tyre = tyre

    def milage (self):
        print("milage of this car ") 
        
        
class tata(car):                #child class
    pass

t = tata("solid1" , "v8" , "radial1")
print(t)
print(t.milage())

# %% [markdown]
# ### multilevel

# %%
class bank :             # perents class 
    def transaction(self) :
        print("total transaction value ")
    def account_opening(self):
        print("this will show you your account open status ")
    def deposite(self):
        print("this will show your deposited amount")


class HDFC_bank(bank):             # child class
    def hdfc_to_icici(self):
        print("this will show you all the transaction happend to icici throuhg hdfc")

class icici(HDFC_bank):          # child class
    pass

# %%
object = bank()

# %%
object1 = HDFC_bank()

# %%
object1.deposite()
# Out:
# this will show your deposited amount

# %%
object2 = icici()

# %%
object2.transaction()
# Out:
# total transaction value

# %%
object2.hdfc_to_icici()
# Out:
# this will show you all the transaction happend to icici throuhg hdfc

# %% [markdown]
# ### Multiple

# %%
class bank :
    def transaction(self) :
        print("total transaction value ")
    def account_opening(self):
        print("this will show you your account open status ")
    def deposite(self):
        print("this will show your deposited amount")
    def test(self):                          # override code
        print("this is a test method form bank class ")


class HDFC_bank:
    def hdfc_to_icici(self):
        print("this will show you all the transaction happend to icici throuhg hdfc")
    def test(self):           #override code
        print("this is a test method form hdfc bank ")

class ineron_bank:
    def account_status_icici(self):
        print("print a account status in icici ")

class icici(HDFC_bank, bank,  ineron_bank):      # multiple inheritence
    pass

# %%
obj4 = icici()

# %%
obj4.account_opening()
# Out:
# this will show you your account open status

# %%
obj4.test()
# Out:
# this is a test method form hdfc bank

# %% [markdown]
# ### hirerchical inheritence

# %%
# Parent class
class Vehicle:
    def start(self):
        print("Vehicle started")

# Child class 1
class Car(Vehicle):
    def drive(self):
        print("Driving a car")

# Child class 2
class Bike(Vehicle):
    def ride(self):
        print("Riding a bike")

# %%
# Creating objects of child classes
c = Car()
b = Bike()

# Access parent method from both child classes
c.start()  # Inherited from Vehicle
c.drive()  # Car-specific method

b.start()  # Inherited from Vehicle
b.ride()   # Bike-specific method
# Out:
# Vehicle started
# Driving a car
# Vehicle started
# Riding a bike

# %% [markdown]
# ### hybrid inheritence

# %%
# Parent class
class Vehicle:
    def general_info(self):
        print("Vehicles are used for transportation.")

# Child class 1 (inherits from Vehicle)
class Car(Vehicle):
    def car_info(self):
        print("Car has 4 wheels.")

# Child class 2 (inherits from Vehicle)
class Bike(Vehicle):
    def bike_info(self):
        print("Bike has 2 wheels.")

# Grandchild class (inherits from both Car and Bike)
class ElectricBike(Car, Bike):
    def electric_info(self):
        print("Electric bike runs on battery.")

# %%
# Create object of ElectricBike
ebike = ElectricBike()

# Access methods
ebike.general_info()   # From Vehicle
ebike.car_info()       # From Car
ebike.bike_info()      # From Bike
ebike.electric_info()  # Own method
