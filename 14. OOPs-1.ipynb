# %%
class person:

    def __init__ (self, name, age, profession):
        self.name = name
        self.age = age
        self.profession = profession

# %%
object = person("ratan", 30, "marketing")

# %%
object.name
# Out:
# 'ratan'

# %%
object.age
# Out:
# 30

# %%
object1 = person("rohit", 30, "sales")

# %%
object1.name
# Out:
# 'rohit'

# %%
class person:

    def __init__ (self, name, age, profession):
        self.name = name2
        self.age = age
        self.profession = profession

# %%
obj = person("rohit", 30, "sales")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 obj = person("rohit", 30, "sales")
#
# Cell In[12], line 4, in person.__init__(self, name, age, profession)
#       3 def __init__ (self, name, age, profession):
# ----> 4     self.name = name2
#       5     self.age = age
#       6     self.profession = profession
#
# NameError: name 'name2' is not defined

# %%
class person:

    def __init__ (self, name, age, profession):
        self.age1 = name
        self.last_name = age
        self.profession = profession

# %%
obj2 = person("rohit", 30, "sales")

# %%
obj2.age1
# Out:
# 'rohit'

# %%
obj2.last_name
# Out:
# 30

# %%
class person:

    def __init__ (self, name, age, profession):
        self.name = name
        self.age = age
        self.profession = profession

    def __init__ (self, name, age, profession, hobby):
        self.name = name
        self.age = age
        self.profession = profession
        self.hobby = hobby
        
    def __init__ (self, name, profession):
        self.name = name
        self.profession = profession

# %%
o1 = person("rohit",  "sales"  )

# %%
o1.profession
# Out:
# 'sales'

# %%
a = 10
a = 20
a = 30

# %%
a
# Out:
# 30

# %%
class person:

    def __init__ (self, name, dob, profession):
        self.name = name
        self.dob = dob
        self.profession = profession

    def age (self, current_year):
        "my first doc string"
        self.current_year = current_year
        return self.current_year - self.dob

# %%
obj = person("rohit", 1990, "sales")

# %%
obj.name
# Out:
# 'rohit'

# %%
obj.age(2026)
# Out:
# 36

# %%
class person:

    def age (self, current_year, dob):
        "my first doc string"
        self.current_year = current_year
        self.dob = dob
        return self.current_year - self.dob

# %%
obj2 = person()

# %%
obj2.age(2026, 1990)
# Out:
# 36
