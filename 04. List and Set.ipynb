# %% [markdown]
# ## List

# %%
l1 = [1,2,3,4, "a","b","c"]

# %%
l1[2]
# Out:
# 3

# %%
l1[:10]
# Out:
# [1, 2, 3, 4, 'a', 'b', 'c']

# %%
l1[12]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 l1[12]
#
# IndexError: list index out of range

# %%
l1[9:]
# Out:
# []

# %%
l1[::-1]
# Out:
# ['c', 'b', 'a', 4, 3, 2, 1]

# %%
l1 + l1
# Out:
# [1, 2, 3, 4, 'a', 'b', 'c', 1, 2, 3, 4, 'a', 'b', 'c']

# %%
l1*2
# Out:
# [1, 2, 3, 4, 'a', 'b', 'c', 1, 2, 3, 4, 'a', 'b', 'c']

# %%
l1[3] = 44

# %%
l1
# Out:
# [1, 2, 3, 44, 'a', 'b', 'c']

# %%
l1[6] = "C++"

# %%
l1
# Out:
# [1, 2, 3, 44, 'a', 'b', 'C++']

# %%
l3 = l1.copy()

# %%
l2
# Out:
# [1, 2, 3, 44, 'a', 'b', 'C++']

# %%
l1
# Out:
# [1, 2, 3, 44, 'a', 'b', 'C++']

# %%
l1.append("red")

# %%
l1
# Out:
# [1, 2, 3, 44, 'a', 'b', 'C++', 'red']

# %%
l1.append([1,2])

# %%
l1
# Out:
# [1, 2, 3, 44, 'a', 'b', 'C++', 'red', [1, 2]]

# %%
l1.append("yellow")

# %%
l1
# Out:
# [1, 2, 3, 44, 'a', 'b', 'C++', 'red', [1, 2], 'yellow']

# %%
l1.extend(3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 l1.extend(3)
#
# TypeError: 'int' object is not iterable

# %%
l1.extend((1,2,3))

# %%
l1.extend("amit")

# %%
l1
# Out:
# [1,
#  2,
#  3,
#  44,
#  'a',
#  'b',
#  'C++',
#  'red',
#  [1, 2],
#  'yellow',
#  1,
#  2,
#  3,
#  'a',
#  'm',
#  'i',
#  't']

# %%
l1.insert(2, 55)

# %%
l1
# Out:
# [1,
#  2,
#  55,
#  3,
#  44,
#  'a',
#  'b',
#  'C++',
#  'red',
#  [1, 2],
#  'yellow',
#  1,
#  2,
#  3,
#  'a',
#  'm',
#  'i',
#  't']

# %%
l1.pop()
# Out:
# 't'

# %%
l1.pop()
# Out:
# 'a'

# %%
l1.remove("yellow")

# %%
l1
# Out:
# [1, 2, 55, 3, 44, 'a', 'b', 'C++', 'red', [1, 2], 1, 2, 3]

# %%
l1.reverse()

# %%
l1
# Out:
# [3, 2, 1, [1, 2], 'red', 'C++', 'b', 'a', 44, 3, 55, 2, 1]

# %%
l1[::-1]
# Out:
# [1, 2, 55, 3, 44, 'a', 'b', 'C++', 'red', [1, 2], 1, 2, 3]

# %%
l1
# Out:
# [3, 2, 1, [1, 2], 'red', 'C++', 'b', 'a', 44, 3, 55, 2, 1]

# %%
l1.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 l1.sort()
#
# TypeError: '<' not supported between instances of 'list' and 'int'

# %%
l1.clear()

# %%
l1
# Out:
# []

# %%
l2 = [1,2,5,76,8,4,3,3,2,5,67,7,]

# %%
l2.sort()

# %%
l2
# Out:
# [1, 2, 2, 3, 3, 4, 5, 5, 7, 8, 67, 76]

# %%
l2.sort(reverse=True)

# %%
l2
# Out:
# [76, 67, 8, 7, 5, 5, 4, 3, 3, 2, 2, 1]

# %%
76 in l2
# Out:
# True

# %%
l1 is l2
# Out:
# False

# %%
l3 in l2
# Out:
# False

# %%
l3 = [3,2,4,5,7]

# %%
l3 in l2
# Out:
# False

# %%
l3
# Out:
# [3, 2, 4, 5, 7]

# %%
l2
# Out:
# [76, 67, 8, 7, 5, 5, 4, 3, 3, 2, 2, 1]

# %%
l4 = [5,5,4,3, [4,3]]

# %%
l4 in l2
# Out:
# False

# %%
l5 = [4,3]

# %%
l5 in l4
# Out:
# True

# %%
l4
# Out:
# [5, 5, 4, 3]

# %%
5 in l2
# Out:
# True

# %%
l5
# Out:
# [4, 3]

# %% [markdown]
# ## Set

# %%
s1 = {}

# %%
type(s1)
# Out:
# dict

# %%
s1 = {1,2,3,4,3,4,1,4}

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s1[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 s1[2]
#
# TypeError: 'set' object is not subscriptable

# %%
s1[:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 s1[:]
#
# TypeError: 'set' object is not subscriptable

# %%
s1 + s1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 s1 + s1
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
s1*2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 s1*2
#
# TypeError: unsupported operand type(s) for *: 'set' and 'int'

# %%
s1[2] = 33
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 s1[2] = 33
#
# TypeError: 'set' object does not support item assignment

# %%
s2 = {3,4,5,6}

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s2
# Out:
# {3, 4, 5, 6}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s1.update([6])

# %%
s1
# Out:
# {1, 2, 3, 4, 6}

# %%
s1.update(["a"])

# %%
s1
# Out:
# {1, 2, 3, 4, 6, 'a'}

# %%
s1.update([7,8,9])

# %%
s1
# Out:
# {0, 1, 2, 3, 4, 6, 7, 8, 9, 'a'}

# %%
s1
# Out:
# {0, 1, 2, 3, 4, 6, 7, 8, 9, 'a'}

# %%
s2
# Out:
# {3, 4, 5, 6}

# %%
s1.remove(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 s1.remove(5)
#
# KeyError: 5

# %%
s1.discard(5)

# %%
s1.remove(4)

# %%
s1
# Out:
# {0, 1, 2, 3, 6, 7, 8, 9, 'a'}

# %%
s1.discard(6)

# %%
s1
# Out:
# {0, 1, 2, 3, 7, 8, 9, 'a'}

# %%
s1.pop()
# Out:
# 0

# %%
s1.pop()
# Out:
# 1

# %%
s1
# Out:
# {2, 3, 7, 8, 9, 'a'}

# %%
s1.add(1)

# %%
s1.add((22))

# %%
s1
# Out:
# {1, 2, 22, 3, 7, 8, 9, 'a'}

# %%
s1 = {1,2,3,4}
s2 = {3,4,5,6}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s1.difference(s2)
# Out:
# {1, 2}

# %%
s1.intersection(s2)
# Out:
# {3, 4}

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s1.difference_update(s2)

# %%
s1
# Out:
# {1, 2}

# %%
s1 = {1,2,3,4}
s2 = {3,4,5,6}

# %%
s1.intersection_update(s2)

# %%
s1
# Out:
# {3, 4}

# %%
s3 = {1,3,5,6}
s4 = {3,5}

# %%
s3.issubset(s4)
# Out:
# False

# %%
s4.issubset(s3)
# Out:
# True

# %%
s4.issuperset(s3)
# Out:
# False

# %%
s3.issuperset(s4)
# Out:
# True

# %%
s5 = {1,2,3,4,5}

# %%
s5.remove(5)

# %%
s5
# Out:
# {1, 2, 3, 4}

# %%
fs = frozenset(s5)

# %%
3 in s5
# Out:
# True

# %%
s1 is s3
# Out:
# False

# %%
fs1 = frozenset({3,4,5,6})

# %%
fs
# Out:
# frozenset({1, 2, 3, 4})

# %%
fs1
# Out:
# frozenset({3, 4, 5, 6})

# %%
fs1.union(fs)
# Out:
# frozenset({1, 2, 3, 4, 5, 6})
