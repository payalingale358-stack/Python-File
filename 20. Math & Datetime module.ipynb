# %%
import math

# %%
math.factorial(5)
# Out:
# 120

# %%
math.ceil(30.57)
# Out:
# 31

# %%
math.floor(30.57)
# Out:
# 30

# %%
math.lcm(20, 45, 60)
# Out:
# 180

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.radians(45)
# Out:
# 0.7853981633974483

# %%
math.pow(5, 2)
# Out:
# 25.0

# %%
math.comb(6, 2)
# Out:
# 15

# %%
math.perm(6,2)
# Out:
# 30

# %%
math.sqrt(20)
# Out:
# 4.47213595499958

# %%
math.tau
# Out:
# 6.283185307179586

# %%
type(math)
# Out:
# module

# %%
import datetime as dt

# %%
type(dt)
# Out:
# module

# %%
from datetime import date

today = date.today()
print("Today's date:", today)
print("Formatted date:", today.strftime("%Y-%m-%d"))
# Out:
# Today's date: 2026-01-12
# Formatted date: 2026-01-12

# %%
from datetime import time

current_time = time(14, 30, 45)
print("Current time:", current_time)
print("Formatted time:", current_time.strftime("%H:%M:%S"))
# Out:
# Current time: 14:30:45
# Formatted time: 14:30:45

# %%
from datetime import datetime

now = datetime.now()
print("Current date and time:", now)
print("Formatted datetime:", now.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Current date and time: 2026-01-12 09:52:35.301446
# Formatted datetime: 2026-01-12 09:52:35

# %%
from datetime import timedelta

delta = timedelta(days=5, hours=3)
print("Delta:", delta)
print("Total seconds in delta:", delta.total_seconds())
# Out:
# Delta: 5 days, 3:00:00
# Total seconds in delta: 442800.0

# %%
from datetime import datetime, timezone

now = datetime.now(timezone.utc)
print("Current UTC time:", now)
# Out:
# Current UTC time: 2026-01-12 04:24:42.299766+00:00

# %%
from datetime import date, time, datetime

d = date(2024, 7, 27)
t = time(15, 30, 45)
dt = datetime(2024, 7, 27, 15, 30, 45)

# %%
d
# Out:
# datetime.date(2024, 7, 27)

# %%
t
# Out:
# datetime.time(15, 30, 45)

# %%
dt
# Out:
# datetime.datetime(2024, 7, 27, 15, 30, 45)

# %%
dt.strftime("%Y-%m-%d %H:%M:%S")
# Out:
# '2024-07-27 15:30:45'

# %%
from datetime import datetime, timedelta

now = datetime.now()
now
# Out:
# datetime.datetime(2026, 1, 12, 9, 58, 18, 555189)

# %%
tomorrow = now + timedelta(days=2)
tomorrow
# Out:
# datetime.datetime(2026, 1, 14, 9, 58, 18, 555189)

# %%
difference = tomorrow - now
print("Difference:", difference)
# Out:
# Difference: 2 days, 0:00:00

# %%
from datetime import time

t = time(14, 30)
t
# Out:
# datetime.time(14, 30)

# %%
new_time = t.replace(minute=45)
print("Updated time:", new_time)
# Out:
# Updated time: 14:45:00

# %%
import datetime as dt

# %%
todaydate = dt.date.today()

# %%
todaydate.strftime("%Y/%m/%d")
# Out:
# '2026/01/12'

# %%
todaydate.strftime("%d/%m/%Y")
# Out:
# '12/01/2026'
